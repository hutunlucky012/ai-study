# %%
import os
from openai import OpenAI

# 从环境变量获取 DeepSeek API Key
api_key = os.getenv("DEEPSEEK_API_KEY")
if not api_key:
    raise ValueError("请设置 DEEPSEEK_API_KEY 环境变量")

# 初始化 DeepSeek 客户端
client = OpenAI(
    api_key=api_key,
    base_url="https://api.deepseek.com/v1",  # DeepSeek API 的基地址
)

# %%
def send_messages(messages, tool_choice="auto"):
    response = client.chat.completions.create(
        model="deepseek-chat",
        messages=messages,
        tools=tools,
        tool_choice=tool_choice
    )
    return response.choices[0].message

# %%
tools = [
    {
        "type": "function",
        "function": {
            "name": "get_weather",
            "description": "Get weather of an location, the user should supply a location first",
            "parameters": {
                "type": "object",
                "properties": {
                    "location": {
                        "type": "string",
                        "description": "The city and state, e.g. San Francisco, CA",
                    }
                },
                "required": ["location"]
            },
        }
    },
]

# %%
messages = [{"role": "user", "content": "How's the weather in Shanghai?"}]
message = send_messages(messages, "required")

# %%
print(f"User>\t {messages[0]['content']}")
# Out:
# User>	 How's the weather in Shanghai?

# %%
tool = message.tool_calls[0]

messages.append(message)

# %%
message
# Out:
# ChatCompletionMessage(content='', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_00_v009jrEVQFcrF4Em1A9nqVNA', function=Function(arguments='{"location": "Shanghai"}', name='get_weather'), type='function', index=0)])

# %%
tool
# Out:
# ChatCompletionMessageToolCall(id='call_00_v009jrEVQFcrF4Em1A9nqVNA', function=Function(arguments='{"location": "Shanghai"}', name='get_weather'), type='function', index=0)

# %%
# 模拟 search_web 工具调用结果（直接返回24度）
messages.append({"role": "tool", "tool_call_id": tool.id, "content": "24℃"})
message = send_messages(messages)
print(f"Model>\t {message.content}")
# Out:
# Model>	 The current weather in Shanghai is 24°C. That's a pleasant, mild temperature - perfect for outdoor activities!
